# %%
a=input("enter any numbar:")
b=input("enter any number:")
c=a+b
print(c)
# Out:
# enter any numbar: 10
# enter any number: 10
# 1010

# %%
# typecasting
a=int(input("enter any number"))
b=int(input("enter any number"))
c=a+b
print(c)
# Out:
# enter any number 50
# enter any number 20
# 70

# %%
#control flow statement
#conditional statement
#if 
num=200
if num%2==0:
    print(num,"is an even number")
# Out:
# 200 is an even number

# %%
# if else 
num=int(input("enter any number:"))
if num%2==0:
    print(num,"is an even number")
else:
    print(num,"is an odd number")
# Out:
# enter any number: 18
# 18 is an even number

# %%
num=int(input("enter any number:"))
if num%3==0:
    print(num,"is divisible by 3")
else:
    print(num,"is not divisible by 3")
# Out:
# enter any number: 8
# 8 is not divisible by 3

# %%
age=int(input("enter the age"))
if age>=1:
    if age>=18:
     print("eligible to vote")
    else:
     print("not eligible to vote")
else:
 print("invalid age lnput")
# Out:
# enter the age 15
# not eligible to vote

# %%
num=int(input("enter any number"))
if ((num%100)%3)==0:
        print(num,"last digit divisible by 3")
else:print (num,"last digit not divisible by 3")
# Out:
# enter any number 998
# 998 last digit not divisible by 3

# %%
sci=int(input("enter marks: "))
lang=int(input("enter marks: "))
maths=int(input("enter marks: "))
obtained_marks=sci+lang+maths
print(obtained_marks)
per=(obtained_marks/300)*100
print("percatage:",per,"%")
if per>=65:
    print("1st division")
elif per>=50:
    print("2nd division")
elif per>=33:
    print("3rd division")
else:
    print(fail)

# %%
a=int(input("enter number"))
if a>0:
    if a%2==0:
        print("positive even number")
    else:
        print("positive odd number")
elif a==0:
    print("negative number")
else:
    print("zero number")
# Out:
# enter number 0
# negative number

# %%
s1=int(input("side 1"))
s2=int(input("side 2"))
s3=int(input("side 3"))
if s1+s2>s3 and s2+s3>s1 and s1+s3>s2:
    if s1==s2==s3:
        print("equilateral")
    elif s1==s2 and s2==s3 and s3==s1:
        print("isosceles")
    else:
        print("scalence")
else:
    print("not triangle")
# Out:
# side 1 10
# side 2 10
# side 3 10
# equilateral
