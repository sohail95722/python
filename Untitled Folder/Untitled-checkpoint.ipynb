# %%
a=[1,2,3]
b=a
b[0]=5
print(a)
# Out:
# [5, 2, 3]

# %%
x = 10  
y = 5  
if x > y:  
    print("x is greater")  
else:  
    print("y is greater")
# Out:
# x is greater

# %%
x = 15  
y = 9  
if x + y > 20:  
    if x > y:  
        print("A")  
    elif y != 9:  
        print("B")  
    else:  
        print("C")  
else:  
        if x > 20:  
            print("D")  
        elif y > 10:  
            print("E")  
        else:  
            print("F")
# Out:
# A
